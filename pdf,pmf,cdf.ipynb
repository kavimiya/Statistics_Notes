# %% [markdown]
# ## Random Variable :
#
# `A random  variable is the result of a chance event, that you may measure or count`. `It is a variable that assumes numerical values associated with the random outcomes of an experiment where one (and only one) numerical value is assigned to each sample point`. Let us consider the example of flipping a coin once, wherein the possible outcome is either a head or tail denoted by 1 and 0 respectively. Another example is the random possible outcome while rolling a dice which is one among the following (1,2,3,4,5,6).The random variable is of two types viz.,
#
# * Discrete Random Variable
# * Continuous Random Variable

# %% [markdown]
# ## Discrete Random Variable :
# A discrete random variable is variable which takes the numerical outcome of the chance event or any countable number of possible values. An example is the number of people visiting the hospital in a day. It can never be a decimal value.
#
# ## Continuous Random Variable :
# A random variable is said to be a continuous random variable if it takes infinite number of values in an interval. The probability of the random variable taking any one specific value is zero.The random variable "X" can take any possible values in an interval of real numbers. For example X ∈ [0,1].

# %% [markdown]
# ## What is Probability Distribution & Why?
# Probability Distribution is a function which lists all the possible outcomes a random variable can take, along with its corresponding probability of occurrence. Although the random variable has the ability to assume a random value it lacks the capability to capture the probability of occurrence those value. The probability distribution can also be plotted as a graph.

# %% [markdown]
# ## PDF (Probability Density Function):-

# %% [markdown]
# ## Probability Density Function :
# The probability density function is the statistical function that defines the probability distribution of a `continuous random variable`. When the probability density function is graphically plotted, the area under the curve will indicate the interval in which the variable will fall. The total area in this interval of the graph equals the probability of a discrete random variable occurring. The sum of all probabilities should be equal to 1. `It is impossible to find the probability of a particular continuous random variable since the summation of probability of all random variables within an interval will be infinite.`

# %% [markdown]
# ![image.png](attachment:09ce40a2-5ef3-46ad-9f7e-e9c986fb6326.png)

# %% [markdown]
# ## PDF (Probability Density Function):
#
# * PDF is used for continuous random variables.
# * It gives the relative likelihood of the random variable taking on a particular value within a given range.
# * Unlike PMF, PDF doesn't directly give probabilities but rather densities. The probability of a continuous random variable falling within a specific range is given by the integral of the PDF over that range.
# * For example, if you have a normally distributed continuous variable (like height or weight), the PDF would describe the likelihood of observing different values within a given range.

# %% [markdown]
# ## PMF (Probability Mass Function):-

# %% [markdown]
# The probability distribution of a `Discrete Random Variable is called as Probability Mass Function or PMF`. The probability mass function, f(x) = P(X = x), of a discrete random variable X has the following properties:
#
# All probabilities are positive : P(x) ≥ 0.
# Any event in the distribution has a probability of happening of between 0 and 1. 0 ≤ P(x) ≤ 1. (e.g. 0% and 100%).
# The sum of all probabilities is 1. So ∑P(x) = 1.

# %% [markdown]
# ![image.png](attachment:87616d97-2630-41e7-ab14-74099265f033.png)

# %%
PMF is a statistical term that describes the probability distribution of the Discrete random variable

# %% [markdown]
# People often get confused between PDF and PMF. The PDF is applicable for continues random variable while PMF is applicable for discrete random variable For e.g, Throwing a dice (You can only select 1 to 6 numbers (countable) )

# %% [markdown]
# ## Cumulative Distributive Function :
# The cumulative distribution function is is applicable for both `discrete and continuous random variable`.The cumulative distribution function gives the cumulative value from negative infinity up to a random variable X and is defined by the following notation:
#
# F(x) = P(X≤x)
#
# I hope this article helped you with random variables, probability distributions and the differences between pmf, pdf, cdf. Probability distributions help in modelling and predicting different outcomes of various events in real life.

# %% [markdown]
# ![image.png](attachment:8b8d6db1-58be-4c37-81a1-4e22d234b380.png)

# %% [markdown]
# PMF is a way to describe distribution but its only applicable for discrete random variables and not for continuous random variables. The cumulative distribution function is applicable for describing the distribution of random variables either it is continuous or discrete
#
# For example, if X is the height of a person selected at random then F(x) is the chance that the person will be shorter than x. If F(180 cm)=0.8. then there is an 80% chance that a person selected at random will be shorter than 180 cm (equivalently, a 20% chance that they will be taller than 180cm)

# %% [markdown]
# ![image.png](attachment:ea294ea6-0e17-4791-9e1b-193968997baf.png)![image.png]

# %% [markdown]
# ![image.png](attachment:9cde4b72-aca1-42e6-b839-0c0c3c542f36.png)
